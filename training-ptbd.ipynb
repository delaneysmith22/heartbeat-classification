# %%
import numpy as np 
import pandas as pd 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.utils import class_weight
from sklearn.utils import shuffle
from keras.utils.np_utils import to_categorical

# %%
# Load Data
PTBD_train_data = pd.read_csv('/kaggle/input/ptbd-data/PTBD_train.csv')
PTBD_test_data = pd.read_csv('/kaggle/input/ptbd-data/PTBD_test.csv')

# %%
def pre_process(train):
    X_train = np.asarray(train.drop(columns=['187']))
    y_train = np.asarray(train['187'])
    y_train_cat = to_categorical(y_train)
    return X_train,y_train,y_train_cat

# %%
X_train_ptbd, labels_ptbd, y_train_ptbd = pre_process(PTBD_train_data)
X_train_new_ptbd = X_train_ptbd.reshape(X_train_ptbd.shape[0],187,1)

X_test_ptbd, test_labels_ptbd, y_test_ptbd = pre_process(PTBD_test_data)
X_test_new_ptbd = X_test_ptbd.reshape(X_test_ptbd.shape[0],187,1)

# %%
from keras import layers
from keras.layers import Dense, Dropout, BatchNormalization, Flatten
from keras.layers import Conv1D, GlobalAveragePooling1D, AveragePooling1D
from keras.models import Sequential,save_model,load_model
from keras import optimizers
from keras.callbacks import LearningRateScheduler
import tensorflow as tf

# %%
def build_model():
    model = Sequential()
    
    # Convolutional block 1
    model.add(Conv1D(256,2,strides=1,activation = 'relu',input_shape=(187,1)))
    model.add(Conv1D(256,2,strides=1,activation = 'relu'))
    #model.add(Conv1D(256,2,strides=1,activation = 'relu'))

    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    
    # Convolutional block 2
    model.add(Conv1D(256,2,strides=1,activation = 'relu'))
    model.add(Conv1D(256,2,strides=1,activation = 'relu'))
    #model.add(Conv1D(256,2,strides=1,activation = 'relu'))

    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    
    model.add(GlobalAveragePooling1D())
              
    model.add(Dense(128,activation = 'relu'))
    
    model.add(Dense(2, activation='softmax'))          
    
    return model

# %%
# Fine tunes the learning after the 80th epoch
def lr_decay(epoch):
    if epoch < 80:
        learn_rate = 0.001
    else: 
        learn_rate = 0.0001
    return learn_rate

# %%
""" Define focal loss function as per 
    https://www.dlology.com/blog/
    multi-class-classification-with-focal-loss-for-imbalanced-datasets/""" 
def focal_loss_fnc(gamma,alpha):
    
    gamma = float(gamma)
    alpha = float(alpha)
    
    def focal_loss_fixed(y_true, y_pred):
        """Focal loss for multi-classification
        FL(p_t)=-alpha(1-p_t)^{gamma}ln(p_t)
        Notice: y_pred is probability after softmax
        gradient is d(Fl)/d(p_t) not d(Fl)/d(x) as described in paper
        d(Fl)/d(p_t) * [p_t(1-p_t)] = d(Fl)/d(x)
        Focal Loss for Dense Object Detection
        https://arxiv.org/abs/1708.02002

        Arguments:
            y_true {tensor} -- ground truth labels, shape of [batch_size, num_cls]
            y_pred {tensor} -- model's output, shape of [batch_size, num_cls]
       Keyword Arguments:
            gamma {float} -- (default: {2.0})
            alpha {float} -- (default: {4.0})

        Returns:
            [tensor] -- loss.
        """
        epsilon = 1.e-9
        y_true = tf.convert_to_tensor(y_true, tf.float32)
        y_pred = tf.convert_to_tensor(y_pred, tf.float32)

        model_out = tf.add(y_pred, epsilon)
        ce = tf.multiply(y_true, -tf.math.log(model_out))
        weight = tf.multiply(y_true, tf.pow(tf.subtract(1., model_out), gamma))
        fl = tf.multiply(alpha, tf.multiply(weight, ce))
        reduced_fl = tf.reduce_max(fl, axis=1)
        return tf.reduce_mean(reduced_fl)
    return focal_loss_fixed

# %%
def train_model(model,X_train,y_train,X_valid,y_valid,filename,n_epochs=100,batch_size=400,
                learn_rate=0.001,focal_loss=True,gamma=2,alpha=0.25):
    
    if focal_loss:
        loss = focal_loss_fnc(gamma,alpha) # still need to define
        
    else:
        loss = 'categorical_crossentropy'
    
    adam = optimizers.Adam(learning_rate=learn_rate)
    
    # may want to change metrics later
    model.compile(optimizer=adam,loss=loss,metrics=['accuracy'])
    
    # Reduce learning rate to 0.0001 after 80th epoch
    callbacks = LearningRateScheduler(lr_decay)
        
    history = model.fit(X_train,y_train,validation_data=(X_valid,y_valid), epochs=n_epochs,batch_size=batch_size,callbacks=callbacks)
    
    print("\nEvaluating...", flush=True)
    print('Training data:', flush=True)
    loss, acc = model.evaluate(X_train, y_train, verbose=1)
    print("  Training : loss %.3f - acc %.3f" % (loss, acc))
    
    print('Saving model...', flush=True)
    save_model(
    model,
    filename,
    overwrite=True,
    include_optimizer=True,
    save_format=None,
    signatures=None,
    options=None
    )
    
    return model, history

# %%
filename = "model_ptbd_wout_focal_loss"
model_wout_focal_loss,history_wout_focal_loss = train_model(build_model(),
                                                            X_train_new_ptbd,
                                                            y_train_ptbd,
                                                            X_test_new_ptbd,
                                                            y_test_ptbd,
                                                            filename,
                                                            focal_loss=False
                                                            )
hist_df_wout_focal_loss = pd.DataFrame(history_wout_focal_loss.history)
hist_df_wout_focal_loss.to_csv("history_wout_focal_loss.csv", index=False)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 2s 72ms/step - loss: 0.5067 - accuracy: 0.7423 - val_loss: 0.6382 - val_accuracy: 0.7133
# Epoch 2/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.3916 - accuracy: 0.8246 - val_loss: 0.6080 - val_accuracy: 0.7133
# Epoch 3/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.2984 - accuracy: 0.8744 - val_loss: 0.6423 - val_accuracy: 0.7133
# Epoch 4/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.2664 - accuracy: 0.8885 - val_loss: 0.6922 - val_accuracy: 0.7133
# Epoch 5/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.2431 - accuracy: 0.8962 - val_loss: 0.6601 - val_accuracy: 0.7133
# Epoch 6/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.2219 - accuracy: 0.9083 - val_loss: 0.7154 - val_accuracy: 0.7133
# Epoch 7/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.1998 - accuracy: 0.9195 - val_loss: 0.5938 - val_accuracy: 0.7133
# Epoch 8/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.1767 - accuracy: 0.9276 - val_loss: 0.6817 - val_accuracy: 0.7133
# Epoch 9/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.1637 - accuracy: 0.9330 - val_loss: 0.5396 - val_accuracy: 0.7133
# Epoch 10/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.1505 - accuracy: 0.9398 - val_loss: 0.4951 - val_accuracy: 0.7133
# Epoch 11/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.1325 - accuracy: 0.9507 - val_loss: 0.5059 - val_accuracy: 0.8397
# Epoch 12/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.1216 - accuracy: 0.9515 - val_loss: 0.4749 - val_accuracy: 0.8516
# Epoch 13/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.1129 - accuracy: 0.9587 - val_loss: 0.4520 - val_accuracy: 0.8417
# Epoch 14/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.1094 - accuracy: 0.9594 - val_loss: 0.4612 - val_accuracy: 0.7985
# Epoch 15/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.1038 - accuracy: 0.9618 - val_loss: 0.8618 - val_accuracy: 0.5470
# Epoch 16/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.0929 - accuracy: 0.9666 - val_loss: 0.4167 - val_accuracy: 0.8260
# Epoch 17/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0891 - accuracy: 0.9674 - val_loss: 0.4165 - val_accuracy: 0.8310
# Epoch 18/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0869 - accuracy: 0.9682 - val_loss: 0.4093 - val_accuracy: 0.8101
# Epoch 19/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.0822 - accuracy: 0.9701 - val_loss: 0.2702 - val_accuracy: 0.8879
# Epoch 20/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0728 - accuracy: 0.9751 - val_loss: 0.5994 - val_accuracy: 0.7971
# Epoch 21/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0779 - accuracy: 0.9729 - val_loss: 0.5848 - val_accuracy: 0.7636
# Epoch 22/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0740 - accuracy: 0.9721 - val_loss: 0.2603 - val_accuracy: 0.8813
# Epoch 23/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0629 - accuracy: 0.9783 - val_loss: 0.3888 - val_accuracy: 0.8499
# Epoch 24/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0616 - accuracy: 0.9782 - val_loss: 0.3126 - val_accuracy: 0.8683
# Epoch 25/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0624 - accuracy: 0.9783 - val_loss: 0.1559 - val_accuracy: 0.9351
# Epoch 26/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.0592 - accuracy: 0.9809 - val_loss: 0.0794 - val_accuracy: 0.9731
# Epoch 27/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0587 - accuracy: 0.9793 - val_loss: 0.7409 - val_accuracy: 0.8345
# Epoch 28/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0609 - accuracy: 0.9788 - val_loss: 0.0909 - val_accuracy: 0.9665
# Epoch 29/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0532 - accuracy: 0.9807 - val_loss: 0.0950 - val_accuracy: 0.9651
# Epoch 30/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0523 - accuracy: 0.9812 - val_loss: 0.3904 - val_accuracy: 0.8895
# Epoch 31/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0494 - accuracy: 0.9835 - val_loss: 0.1027 - val_accuracy: 0.9623
# Epoch 32/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.0469 - accuracy: 0.9852 - val_loss: 0.8372 - val_accuracy: 0.7977
# Epoch 33/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0568 - accuracy: 0.9776 - val_loss: 0.5405 - val_accuracy: 0.8505
# Epoch 34/100
# 28/28 [==============================] - 2s 65ms/step - loss: 0.0483 - accuracy: 0.9839 - val_loss: 0.3720 - val_accuracy: 0.8683
# Epoch 35/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0440 - accuracy: 0.9843 - val_loss: 0.2218 - val_accuracy: 0.9164
# Epoch 36/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0402 - accuracy: 0.9852 - val_loss: 0.1302 - val_accuracy: 0.9502
# Epoch 37/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0417 - accuracy: 0.9850 - val_loss: 0.2301 - val_accuracy: 0.9178
# Epoch 38/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0422 - accuracy: 0.9855 - val_loss: 0.1282 - val_accuracy: 0.9535
# Epoch 39/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.0379 - accuracy: 0.9871 - val_loss: 0.0770 - val_accuracy: 0.9709
# Epoch 40/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0372 - accuracy: 0.9883 - val_loss: 0.0806 - val_accuracy: 0.9700
# Epoch 41/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0370 - accuracy: 0.9884 - val_loss: 0.0862 - val_accuracy: 0.9761
# Epoch 42/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0336 - accuracy: 0.9886 - val_loss: 0.2455 - val_accuracy: 0.9236
# Epoch 43/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0338 - accuracy: 0.9883 - val_loss: 0.1711 - val_accuracy: 0.9368
# Epoch 44/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0339 - accuracy: 0.9891 - val_loss: 0.1190 - val_accuracy: 0.9629
# Epoch 45/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0325 - accuracy: 0.9891 - val_loss: 0.3673 - val_accuracy: 0.8813
# Epoch 46/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0321 - accuracy: 0.9890 - val_loss: 0.0730 - val_accuracy: 0.9764
# Epoch 47/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0348 - accuracy: 0.9878 - val_loss: 0.9982 - val_accuracy: 0.7793
# Epoch 48/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0321 - accuracy: 0.9891 - val_loss: 0.4079 - val_accuracy: 0.8565
# Epoch 49/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0255 - accuracy: 0.9918 - val_loss: 0.0590 - val_accuracy: 0.9775
# Epoch 50/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0321 - accuracy: 0.9894 - val_loss: 0.0931 - val_accuracy: 0.9654
# Epoch 51/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0266 - accuracy: 0.9913 - val_loss: 0.0562 - val_accuracy: 0.9805
# Epoch 52/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0279 - accuracy: 0.9907 - val_loss: 0.1667 - val_accuracy: 0.9491
# Epoch 53/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0234 - accuracy: 0.9918 - val_loss: 0.0877 - val_accuracy: 0.9659
# Epoch 54/100
# 28/28 [==============================] - 2s 57ms/step - loss: 0.0232 - accuracy: 0.9920 - val_loss: 0.0703 - val_accuracy: 0.9747
# Epoch 55/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0302 - accuracy: 0.9901 - val_loss: 0.1221 - val_accuracy: 0.9516
# Epoch 56/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0240 - accuracy: 0.9924 - val_loss: 0.0379 - val_accuracy: 0.9868
# Epoch 57/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0240 - accuracy: 0.9929 - val_loss: 0.0756 - val_accuracy: 0.9709
# Epoch 58/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0235 - accuracy: 0.9917 - val_loss: 0.1832 - val_accuracy: 0.9244
# Epoch 59/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0233 - accuracy: 0.9924 - val_loss: 0.3239 - val_accuracy: 0.9098
# Epoch 60/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0211 - accuracy: 0.9934 - val_loss: 0.1133 - val_accuracy: 0.9637
# Epoch 61/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0209 - accuracy: 0.9929 - val_loss: 0.3448 - val_accuracy: 0.9098
# Epoch 62/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0240 - accuracy: 0.9920 - val_loss: 0.0545 - val_accuracy: 0.9791
# Epoch 63/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0230 - accuracy: 0.9924 - val_loss: 0.0576 - val_accuracy: 0.9780
# Epoch 64/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0203 - accuracy: 0.9940 - val_loss: 0.2240 - val_accuracy: 0.9442
# Epoch 65/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0208 - accuracy: 0.9918 - val_loss: 0.1025 - val_accuracy: 0.9643
# Epoch 66/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0252 - accuracy: 0.9914 - val_loss: 0.2055 - val_accuracy: 0.9283
# Epoch 67/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0220 - accuracy: 0.9932 - val_loss: 0.1000 - val_accuracy: 0.9687
# Epoch 68/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0279 - accuracy: 0.9907 - val_loss: 0.1727 - val_accuracy: 0.9456
# Epoch 69/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.0221 - accuracy: 0.9923 - val_loss: 0.2567 - val_accuracy: 0.9417
# Epoch 70/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0222 - accuracy: 0.9924 - val_loss: 0.0701 - val_accuracy: 0.9764
# Epoch 71/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.0194 - accuracy: 0.9932 - val_loss: 0.1570 - val_accuracy: 0.9582
# Epoch 72/100
# 28/28 [==============================] - 2s 62ms/step - loss: 0.0162 - accuracy: 0.9948 - val_loss: 0.0669 - val_accuracy: 0.9775
# Epoch 73/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0175 - accuracy: 0.9940 - val_loss: 0.0381 - val_accuracy: 0.9871
# Epoch 74/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0148 - accuracy: 0.9955 - val_loss: 0.1066 - val_accuracy: 0.9681
# Epoch 75/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0159 - accuracy: 0.9948 - val_loss: 0.0775 - val_accuracy: 0.9791
# Epoch 76/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0176 - accuracy: 0.9943 - val_loss: 0.0673 - val_accuracy: 0.9777
# Epoch 77/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0158 - accuracy: 0.9948 - val_loss: 0.1160 - val_accuracy: 0.9574
# Epoch 78/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0154 - accuracy: 0.9945 - val_loss: 0.0859 - val_accuracy: 0.9742
# Epoch 79/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0223 - accuracy: 0.9929 - val_loss: 0.7562 - val_accuracy: 0.8189
# Epoch 80/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0181 - accuracy: 0.9941 - val_loss: 0.4385 - val_accuracy: 0.8903
# Epoch 81/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0130 - accuracy: 0.9958 - val_loss: 0.0865 - val_accuracy: 0.9722
# Epoch 82/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0133 - accuracy: 0.9955 - val_loss: 0.0401 - val_accuracy: 0.9863
# Epoch 83/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0101 - accuracy: 0.9969 - val_loss: 0.0345 - val_accuracy: 0.9874
# Epoch 84/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0095 - accuracy: 0.9973 - val_loss: 0.0266 - val_accuracy: 0.9907
# Epoch 85/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0091 - accuracy: 0.9974 - val_loss: 0.0233 - val_accuracy: 0.9912
# Epoch 86/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0095 - accuracy: 0.9970 - val_loss: 0.0239 - val_accuracy: 0.9920
# Epoch 87/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0092 - accuracy: 0.9970 - val_loss: 0.0252 - val_accuracy: 0.9912
# Epoch 88/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0080 - accuracy: 0.9979 - val_loss: 0.0255 - val_accuracy: 0.9909
# Epoch 89/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0095 - accuracy: 0.9978 - val_loss: 0.0236 - val_accuracy: 0.9923
# Epoch 90/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.0087 - accuracy: 0.9977 - val_loss: 0.0229 - val_accuracy: 0.9918
# Epoch 91/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.0093 - accuracy: 0.9979 - val_loss: 0.0212 - val_accuracy: 0.9929
# Epoch 92/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0091 - accuracy: 0.9973 - val_loss: 0.0233 - val_accuracy: 0.9923
# Epoch 93/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0085 - accuracy: 0.9975 - val_loss: 0.0253 - val_accuracy: 0.9915
# Epoch 94/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0092 - accuracy: 0.9975 - val_loss: 0.0228 - val_accuracy: 0.9929
# Epoch 95/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0082 - accuracy: 0.9979 - val_loss: 0.0269 - val_accuracy: 0.9912
# Epoch 96/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0077 - accuracy: 0.9978 - val_loss: 0.0279 - val_accuracy: 0.9912
# Epoch 97/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0079 - accuracy: 0.9979 - val_loss: 0.0237 - val_accuracy: 0.9929
# Epoch 98/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0070 - accuracy: 0.9982 - val_loss: 0.0278 - val_accuracy: 0.9912
# Epoch 99/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0084 - accuracy: 0.9977 - val_loss: 0.0231 - val_accuracy: 0.9926
# Epoch 100/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0094 - accuracy: 0.9977 - val_loss: 0.0261 - val_accuracy: 0.9912
#
# Evaluating...
# Training data:
# 342/342 [==============================] - 1s 4ms/step - loss: 0.0036 - accuracy: 0.9990
#   Training : loss 0.004 - acc 0.999
# Saving model...
